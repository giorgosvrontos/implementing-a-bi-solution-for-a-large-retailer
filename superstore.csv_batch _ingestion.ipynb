# %%
raw_online_superstore = spark.read.option("inferSchema", "true").option("header", "true").csv("/Volumes/workspace/superstore/raw_superstore_source/superstore_raw_csv/")

# %%
(raw_online_superstore.write
    .format("delta")
    .mode("overwrite")
    .option("delta.columnMapping.mode", "name")
    .saveAsTable("workspace.superstore.bronze_online_superstore") 
)

# %%
display(raw_online_superstore)

# %%
# %sql
select count(*) from workspace.superstore.bronze_online_superstore
